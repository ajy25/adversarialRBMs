# %% [markdown]
# ### Step 1: Load the MNIST dataset, load all necessary modules

# %%
import os, sys
directory_path = os.path.dirname(os.path.abspath("__notebook__"))
sys.path.append('../../')
import numpy as np
np.random.seed(42)
import matplotlib.pyplot as plt
from models import rbm_svm
from torchvision import datasets
from sklearn.preprocessing import StandardScaler
train_dataset = datasets.MNIST(root='./data', train=True, download=True)
scaler = StandardScaler()
X = train_dataset.data.numpy()
n_examples = X.shape[0]
X = X.reshape(n_examples, -1)
X = scaler.fit_transform(X)
y = train_dataset.targets.numpy()
# plt.figure(figsize=(2, 2))
# plt.imshow(scaler.inverse_transform(X[0].reshape(1, -1)).reshape(28, 28), cmap='gray')
fig, axes = plt.subplots(10, 10, figsize=(5, 5))
axes = axes.flatten()
for i in range(100):
    axes[i].imshow(scaler.inverse_transform(X[i].reshape(1, -1))\
                   .reshape(28, 28), cmap='gray')
    axes[i].axis('off')
plt.show()

# %% [markdown]
# ### Step 2: Train the RBM (no adversary)

# %%
model = rbm_svm.RBM(
    n_vis=784,
    n_hid=500
)
stats = model.fit(
    X=X[:2000],
    n_gibbs=20,
    lr=0.001,
    n_epochs=50,
    batch_size=100,
    gamma=0.1,
    gamma_delay=30,
    rng_seed=0,
    verbose_interval=1,
    checkpoint_path=f'{directory_path}/rbm_checkpoints/rbm_mnist_demo.pth'
)
# Out:
# epoch: 00 of 50 | recon_mse: 0.678 | kl_data_model: 548.399 | kl_model_data: -235.587
# epoch: 01 of 50 | recon_mse: 1.46 | kl_data_model: 501.749 | kl_model_data: -244.141
# epoch: 02 of 50 | recon_mse: 0.375 | kl_data_model: 450.795 | kl_model_data: -227.56
# epoch: 03 of 50 | recon_mse: 0.365 | kl_data_model: 484.07 | kl_model_data: -234.196
# epoch: 04 of 50 | recon_mse: 0.83 | kl_data_model: 430.41 | kl_model_data: -228.606
# epoch: 05 of 50 | recon_mse: 0.311 | kl_data_model: 491.986 | kl_model_data: -224.785
# epoch: 06 of 50 | recon_mse: 0.464 | kl_data_model: 515.395 | kl_model_data: -217.29
# epoch: 07 of 50 | recon_mse: 0.34 | kl_data_model: 475.666 | kl_model_data: -216.778
# epoch: 08 of 50 | recon_mse: 0.355 | kl_data_model: 436.515 | kl_model_data: -212.809
# epoch: 09 of 50 | recon_mse: 0.542 | kl_data_model: 451.463 | kl_model_data: -219.083
# epoch: 10 of 50 | recon_mse: 0.32 | kl_data_model: 478.7 | kl_model_data: -223.256
# epoch: 11 of 50 | recon_mse: 0.384 | kl_data_model: 459.161 | kl_model_data: -215.159
# epoch: 12 of 50 | recon_mse: 0.331 | kl_data_model: 438.305 | kl_model_data: -207.276
# epoch: 13 of 50 | recon_mse: 0.242 | kl_data_model: 511.834 | kl_model_data: -225.03
# epoch: 14 of 50 | recon_mse: 0.329 | kl_data_model: 497.421 | kl_model_data: -232.886
# epoch: 15 of 50 | recon_mse: 0.36 | kl_data_model: 463.942 | kl_model_data: -213.785
# epoch: 16 of 50 | recon_mse: 1.901 | kl_data_model: 415.751 | kl_model_data: -219.034
# epoch: 17 of 50 | recon_mse: 0.271 | kl_data_model: 475.571 | kl_model_data: -238.008
# epoch: 18 of 50 | recon_mse: 0.398 | kl_data_model: 426.671 | kl_model_data: -209.608
# epoch: 19 of 50 | recon_mse: 0.432 | kl_data_model: 414.432 | kl_model_data: -200.728
# epoch: 20 of 50 | recon_mse: 1.384 | kl_data_model: 407.63 | kl_model_data: -210.269
# epoch: 21 of 50 | recon_mse: 0.353 | kl_data_model: 422.8 | kl_model_data: -197.387
# epoch: 22 of 50 | recon_mse: 0.385 | kl_data_model: 421.387 | kl_model_data: -201.014
# epoch: 23 of 50 | recon_mse: 0.276 | kl_data_model: 447.831 | kl_model_data: -223.815
# epoch: 24 of 50 | recon_mse: 0.252 | kl_data_model: 424.534 | kl_model_data: -196.902
# epoch: 25 of 50 | recon_mse: 0.252 | kl_data_model: 424.319 | kl_model_data: -204.889
# epoch: 26 of 50 | recon_mse: 1.153 | kl_data_model: 379.298 | kl_model_data: -216.897
# epoch: 27 of 50 | recon_mse: 0.212 | kl_data_model: 450.647 | kl_model_data: -206.439
# epoch: 28 of 50 | recon_mse: 0.252 | kl_data_model: 404.775 | kl_model_data: -204.311
# epoch: 29 of 50 | recon_mse: 0.251 | kl_data_model: 428.079 | kl_model_data: -214.567
# epoch: 30 of 50 | SVM accuracy: 0.958 | SVM precision: 0.998 | SVM sensitivity: 0.918 | recon_mse: 0.316 | kl_data_model: 404.413 | kl_model_data: -213.095
# epoch: 31 of 50 | SVM accuracy: 0.959 | SVM precision: 1.0 | SVM sensitivity: 0.918 | recon_mse: 0.608 | kl_data_model: 535.709 | kl_model_data: -11.127
# epoch: 32 of 50 | SVM accuracy: 0.958 | SVM precision: 0.999 | SVM sensitivity: 0.918 | recon_mse: 0.795 | kl_data_model: 532.132 | kl_model_data: 67.334
# epoch: 33 of 50 | SVM accuracy: 0.94 | SVM precision: 0.962 | SVM sensitivity: 0.918 | recon_mse: 0.345 | kl_data_model: 561.128 | kl_model_data: 93.325
# epoch: 34 of 50 | SVM accuracy: 0.946 | SVM precision: 0.974 | SVM sensitivity: 0.918 | recon_mse: 0.324 | kl_data_model: 518.408 | kl_model_data: 73.774
# epoch: 35 of 50 | SVM accuracy: 0.507 | SVM precision: 0.503 | SVM sensitivity: 1.0 | recon_mse: 0.562 | kl_data_model: 515.067 | kl_model_data: 75.925
# epoch: 36 of 50 | SVM accuracy: 0.5 | SVM precision: 0.5 | SVM sensitivity: 1.0 | recon_mse: 0.257 | kl_data_model: 464.495 | kl_model_data: -180.553
# epoch: 37 of 50 | SVM accuracy: 0.5 | SVM precision: 0.5 | SVM sensitivity: 1.0 | recon_mse: 0.266 | kl_data_model: 368.802 | kl_model_data: -190.838
# epoch: 38 of 50 | SVM accuracy: 0.5 | SVM precision: 0.5 | SVM sensitivity: 1.0 | recon_mse: 0.265 | kl_data_model: 419.768 | kl_model_data: -158.55
# epoch: 39 of 50 | SVM accuracy: 0.5 | SVM precision: 0.5 | SVM sensitivity: 1.0 | recon_mse: 0.376 | kl_data_model: 388.586 | kl_model_data: -200.293
# epoch: 40 of 50 | SVM accuracy: 0.963 | SVM precision: 0.997 | SVM sensitivity: 0.93 | recon_mse: 0.245 | kl_data_model: 359.895 | kl_model_data: -200.557
# epoch: 41 of 50 | SVM accuracy: 0.956 | SVM precision: 0.981 | SVM sensitivity: 0.93 | recon_mse: 0.468 | kl_data_model: 440.811 | kl_model_data: -39.447
# epoch: 42 of 50 | SVM accuracy: 0.959 | SVM precision: 0.988 | SVM sensitivity: 0.93 | recon_mse: 0.289 | kl_data_model: 488.191 | kl_model_data: 16.514
# epoch: 43 of 50 | SVM accuracy: 0.956 | SVM precision: 0.983 | SVM sensitivity: 0.93 | recon_mse: 0.349 | kl_data_model: 364.02 | kl_model_data: -142.978
# epoch: 44 of 50 | SVM accuracy: 0.928 | SVM precision: 0.927 | SVM sensitivity: 0.93 | recon_mse: 0.255 | kl_data_model: 452.137 | kl_model_data: -42.03
# epoch: 45 of 50 | SVM accuracy: 0.778 | SVM precision: 0.702 | SVM sensitivity: 0.964 | recon_mse: 0.378 | kl_data_model: 448.157 | kl_model_data: -45.392
# epoch: 46 of 50 | SVM accuracy: 0.487 | SVM precision: 0.493 | SVM sensitivity: 0.964 | recon_mse: 0.268 | kl_data_model: 380.071 | kl_model_data: -139.95
# epoch: 47 of 50 | SVM accuracy: 0.482 | SVM precision: 0.491 | SVM sensitivity: 0.964 | recon_mse: 0.461 | kl_data_model: 408.463 | kl_model_data: -192.177
# epoch: 48 of 50 | SVM accuracy: 0.482 | SVM precision: 0.491 | SVM sensitivity: 0.964 | recon_mse: 0.325 | kl_data_model: 403.036 | kl_model_data: -186.559
# epoch: 49 of 50 | SVM accuracy: 0.482 | SVM precision: 0.491 | SVM sensitivity: 0.964 | recon_mse: 0.233 | kl_data_model: 384.369 | kl_model_data: -210.51
# epoch: 50 of 50 | SVM accuracy: 0.955 | SVM precision: 0.996 | SVM sensitivity: 0.914 | recon_mse: 0.188 | kl_data_model: 396.715 | kl_model_data: -214.733

# %% [markdown]
# ### Step 3: Visualize training

# %%
def visualize_learning(stats):
    fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(7, 7))
    axs[0].plot(stats['epoch_num'], stats['recon_mse'])
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Reconstruction MSE')
    axs[1].plot(stats['epoch_num'], stats['kl_data_model'])
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('KL(data || model)')
    axs[2].plot(stats['epoch_num'], stats['kl_model_data'])
    axs[2].set_xlabel('Epoch')
    axs[2].set_ylabel('KL(model || data)')
    plt.tight_layout()
visualize_learning(stats)

# %% [markdown]
# ### Step 4: Visualize samples

# %%
model = rbm_svm.load(f'{directory_path}/rbm_checkpoints/rbm_mnist_demo.pth')
samples = model.reconstruct(np.zeros((100, 784)), n_gibbs=20, add_noise=True)
samples = scaler.inverse_transform(samples).clip(0, 255)
fig, axes = plt.subplots(10, 10, figsize=(5, 5))
axes = axes.flatten()
for i in range(100):
    axes[i].imshow(samples[i].reshape(1, -1).reshape(28, 28) , cmap='gray')
    axes[i].axis('off')
plt.show()

# %% [markdown]
# ### Repeat Step 2 for RBM (trained with adversary)

# %%
model = rbm.RBM(
    n_vis=784,
    n_hid=100
)
model.fit_autograd(
    X=X[:2000],
    n_gibbs=10,
    lr=0.001,
    n_epochs=100,
    batch_size=30,
    gamma=0.1,
    gamma_delay=50,
    rng_seed=0,
    verbose_interval=10,
    reduce_lr_on_plateau=False,
    checkpoint_path=f'{directory_path}/rbm_checkpoints/rbm_mnist_demo_adv.pth'
)
# Out:
# epoch: 010 of 100 | cd_loss: -11.76 | recon_mse: 1.124 | kl_data_model: 1.144 | kl_model_data: 1.614
# epoch: 020 of 100 | cd_loss: -9.464 | recon_mse: 0.944 | kl_data_model: 0.005 | kl_model_data: 1.553
# epoch: 030 of 100 | cd_loss: -7.812 | recon_mse: 0.898 | kl_data_model: 0.56 | kl_model_data: 0.56
# epoch: 040 of 100 | cd_loss: -7.288 | recon_mse: 0.821 | kl_data_model: 0.321 | kl_model_data: 1.226
# epoch: 050 of 100 | cd_loss: -0.719 | recon_mse: 0.814 | kl_data_model: 0.17 | kl_model_data: 0.759
# epoch: 060 of 100 | cd_loss: 1.756 | recon_mse: 2.448 | kl_data_model: 1.284 | kl_model_data: -0.312
# epoch: 070 of 100 | cd_loss: -0.631 | recon_mse: 0.763 | kl_data_model: 0.998 | kl_model_data: 0.094
# epoch: 080 of 100 | cd_loss: -0.678 | recon_mse: 0.804 | kl_data_model: 0.475 | kl_model_data: 0.686
# epoch: 090 of 100 | cd_loss: -0.45 | recon_mse: 0.824 | kl_data_model: 0.304 | kl_model_data: 0.722
# epoch: 100 of 100 | cd_loss: 0.817 | recon_mse: 1.654 | kl_data_model: -0.01 | kl_model_data: 1.325

# %% [markdown]
# ### Repeat Step 3 for RBM (trained with adversary)

# %%
model = rbm.load(f'{directory_path}/rbm_checkpoints/rbm_mnist_demo_adv.pth')
samples = model.reconstruct(np.zeros((100, 784)), n_gibbs=200)
fig, axes = plt.subplots(10, 10, figsize=(5, 5))
axes = axes.flatten()
for i in range(100):
    axes[i].imshow(scaler.inverse_transform(samples[i].reshape(1, -1))\
                   .reshape(28, 28), cmap='gray')
    axes[i].axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/andrewyang/Desktop/adversarialRBMs/demos/rbm_demos/mnist_demo.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/andrewyang/Desktop/adversarialRBMs/demos/rbm_demos/mnist_demo.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> model = rbm.load(f'{directory_path}/rbm_checkpoints/rbm_mnist_demo_adv.pth')
#       <a href='vscode-notebook-cell:/Users/andrewyang/Desktop/adversarialRBMs/demos/rbm_demos/mnist_demo.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> samples = model.reconstruct(np.zeros((100, 784)), n_gibbs=200)
#       <a href='vscode-notebook-cell:/Users/andrewyang/Desktop/adversarialRBMs/demos/rbm_demos/mnist_demo.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> fig, axes = plt.subplots(10, 10, figsize=(5, 5))
#
# File ~/Desktop/adversarialRBMs/demos/rbm_demos/../../models/rbm.py:690, in load(checkpoint_path, metadata_path)
#     688 if metadata_path is None:
#     689     metadata_path = ".".join(checkpoint_path.split(".")[:-1]) + ".json"
# --> 690 with open(metadata_path, "r") as json_file:
#     691     metadata = json.load(json_file)
#     692 model = RBM(
#     693     metadata["n_vis"], metadata["n_hid"], metadata["var"]
#     694 )
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/andrewyang/Desktop/adversarialRBMs/demos/rbm_demos/rbm_checkpoints/rbm_mnist_demo_adv.json'
